# %%
1.Explain the different between relative ,absolute,and mixed cell referencing?

# %% [markdown]
# 1. Expailn the different between relative ,absolute,mixed cell refernecing?
# vehicle   prices ** **bold text**
# car        500000
# bycycle    10500
# autorikshaw 25000
#     _1.RELATIVE CELL REFERENCING (B1)(The follow me mode)----it is perfect for list where every row need the exact same math done to its own data
#     ex-if we want double of cell next to car then we can do C2=B2*2
#
#     2.ABSOLUTE REFERENCING (The pinned mode)-----no matter where we go always look at this one specific cell we do this by adding doller
#     ex-for car we type B2=$E$1( if we have a total tax rate 18%) sitting all inalone in cell E1 or something after this if we dragged this down to bycycle and autorikshaw the b2 changes to b3but $E$1 stay pinned
#     we use it for fixed value like tax discount rates.
#
#     3.MIXED REFERENCING(the half locked mode)-----
#      we lock either coloumn or row .it acn move one way not another .if we want to lock the price coloumn (B) ,now we arecalculating there differnt tax scenerio like 5%,12%,18%
#       B2=everything move (relative)
#       $B$1=nothing moves (absolute)
#       $B2=coloumn stays row moves(fixed)
#       B$2=row stays coloumn moves(fixed)
#
#
#
#
#  2. **write a formula to calculate the total sales of car and bycycle only**
#     _Total sales =B2+B3 (relative)
#       B2=cell for car
#       B3=cell for bycycle
#       if absolute then can use =$B$2+$B$3
#
#
#   3.**using the data below write a formula to calculate the averages sales of items priced above 100 but less than 300      **
#   ** -ITEM      PRICE    SALES**
#       A         B         C
#  1   item A      90       1000
#  2   item B      150      1200
#  3   item C      250      1500
#     __   =AVERAGEIFS(C1:C3,B1:B3,">100","<300")
#
#
# 4.**count how many customer names are recorded? **
#   ---50
#
# 5.**calculate the total sales for each row using a   formula ?**
# 6.**calculate the total sales of notebookin the north region only?**
# 7.**create a coloum chart showing total sales by product**?
# 8.**insert a line chart daily sales trend?** **
#
#
# ANSWER --from 4 to 8 via link
